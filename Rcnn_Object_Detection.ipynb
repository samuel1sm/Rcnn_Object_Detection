# %% [markdown]
# <a href="https://colab.research.google.com/github/samuel1sm/Rcnn_Object_Detection/blob/master/Rcnn_Object_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Instalar bibliotecas**

# %%
# !git clone https://github.com/samuel1sm/Rcnn_Object_Detection.git
# %cd Rcnn_Object_Detection/
# Out:
# Cloning into 'Rcnn_Object_Detection'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 12 (delta 1), reused 12 (delta 1), pack-reused 0
# Unpacking objects: 100% (12/12), done.
# /content/Rcnn_Object_Detection/Rcnn_Object_Detection

# %%
# !pip install imutils

# %% [markdown]
# **Baixar pesos**

# %%
# !python detect_with_classifier.py --image imgs/luke.jpg --size "(450, 450)"
# Out:
# 2020-07-28 14:30:00.905330: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# [INFO] loading network...
# 2020-07-28 14:30:02.959209: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-07-28 14:30:02.982071: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-07-28 14:30:02.982850: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla K80 computeCapability: 3.7
# coreClock: 0.8235GHz coreCount: 13 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 223.96GiB/s
# 2020-07-28 14:30:02.982893: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline
  print(path)
  image = cv2.imread(path)

  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()

# %% [markdown]
# **Criação das pastas**

# %%
imShow("After.jpg")
imShow("Before.jpg")
# Out:
# After.jpg
# Before.jpg
